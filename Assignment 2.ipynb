# %% [markdown]
# ## EXERCISE 2:CONDITIONAL

# %% [markdown]
# ## QUESTION 1

# %% [markdown]
# ## Write a program that takes a number as input and print whether it's postive,negetive,or zero.

# %%
num=float(input("Enter a  postive number"))
if num >0:
    print(num, "is an odd number")
elif num <0:
    print(num, "is an evennumber")
else:
    print(num, "is zero")
# Out:
# Enter a  postive number 9
# 9.0 is an odd number

# %% [markdown]
# ## QUESTION 2

# %% [markdown]
# ## Write a program that determined if a year entered by the user is a leap year (Hint:A leap year is divisible by 4,except for century years which must be divisible by 400)

# %%
year=int(input("Enter a year:"))
if year % 4==0 and year % 100!=0:
  print ("leap year") 
else:
  print("not a leap year")
# Out:
# Enter a year: 9
# not a leap year

# %% [markdown]
# ## QUESTION 3

# %% [markdown]
# ## Create a program that compares two numbers and prints whether the first number is greater than,less than,or equal to the second number.

# %%
number1=float(input("Enter the first number"))
number2=int(input("Enter the second number"))
if number1>number2:
  print("the first number is greater than the second number")
elif number1<number2:
    print("the first number is less than the second number")
else:
  print("the first number is equal to the second number")
# Out:
# Enter the first number 6
# Enter the second number 8
# the first number is less than the second number

# %% [markdown]
# # QUESTION 4

# %% [markdown]
# # Write a program that checks if a number is both greater than 10 and less than 100.if it's ,it should print "great!!",else print "nah!!"

# %%
number=int(input("Enter a number"))
if 90>10:
    print("great!!")
    if number<100:
        print("nah!!")
# Out:
# Enter a number 8
# great!!
# nah!!

# %% [markdown]
# # QUESTION 5

# %% [markdown]
# # Create a simple calculator that takes two numbers and an operator (+,-,*,/) as input and performs the corresponding operation.

# %%
num1=float(input("Enter first number:"))
operator=input("Enter operator (+,-,*,/")
num2=float(input("Enter second number:"))
if operator=="+":
   result=num1+num2
if operator=="-":
   result=num1-num2
if operator=="*":
   result=num1*num2
if operator=="/":
   result=num1/num
# Out:
# Enter first number: 7
# Enter operator (+,-,*,/ 5
# Enter second number: 5

# %% [markdown]
# # QUESTION 6

# %% [markdown]
# # Write a program that categorizes a person by age:child (0-12),teenager (13-19), adult (20-64), or senior (65+).

# %%
age=int(input("Enter your age"))
if age>=0 and age<=12:
    print("categorizes:child")
elif age>=13 and age<=19:
    print("categorizes:teenager")
elif age>=20 and age <=60:
    print("categorizes:adult")
elif age>=65:
    print("categorizes:senior")
else:
    print("invalid age entered")
# Out:
# Enter your age 6
# categorizes:child

# %% [markdown]
# # QUSTION 7

# %% [markdown]
# #  Create a program that determines if a triangle is equilateral (all sides equal), isosceles (two sides equal), or scalene (no sides equal) based on three side lengths

# %%
a=float(input("Enter first side"))
b=float(input("Enter second side"))
c=float(input("Enter third side"))
if a+b>c and a+c>b and b+c>a:
    if a==b ==c:
        print("triangel is equilateral")
    elif a==b or b==c or a==c:
        print("triangel is isosceles")
    else:
        print("triangel is scalene")
else:
  print("not a valid triangel")
# Out:
# Enter first side 9
# Enter second side 8
# Enter third side 9
# triangel is isosceles

# %% [markdown]
# ## QUESTION 8

# %% [markdown]
# # Write a program that checks if two strings entered by the user are exactly equal (case-sensitive).

# %%
str1=input("Enter first strings")
str2=input("Enter second strings")
if str1==str2:
  print("the strings is exactly equal.")
else:
  print("the string are not equal.")
# Out:
# Enter first strings 8
# Enter second strings 9
# the string are not equal.

# %% [markdown]
# # QUESTION 9

# %% [markdown]
# # Create a program that compares two strings ignoring case and prints whether they are the same or different.

# %%
str1=input("Enter first string")
str2=input("Enter second string")
if str1==str2:
    print("the string are the same")
else:
    print("the string are different")
# Out:
# Enter first string 5
# Enter second string 7
# the string are different

# %% [markdown]
# # QUESTION 10

# %% [markdown]
# # write a program that checks if a password meets basic criteria: at least 8 characters long and not equal to "password" or "123456"

# %%
password=input("Enter a password:")
if len(password)>=8 and password !="password" and password !="123456":
    print("password is vaild")
else:
    print("print is invalid")
# Out:
# Enter a password: 6
# print is invalid

# %% [markdown]
# # QUESTION 11

# %% [markdown]
# # Create a program that categorized a word as "short" (1-4 letters), "medium" (5-8 letters),or "long" (9+letters).

# %%
word=len("enter a word")
if word>=1 and word<=4:
   print("categorized short")
if word>=5 and word<8:
    print("categorized medium")
elif word>=9:
    print("catergorizes long")
else:
    print("invalid word enterd")
# Out:
# catergorizes long

# %% [markdown]
# # QUESTION 12

# %% [markdown]
# # Write a program that checks if a string contains only digits ,only letters,or a mix of both.

# %%
text=input("enter a string")
if text.isdigit():
    print("the string contains only digits.")
  elif text.isletters():
      print("the string contains only letters.")
else:
    print("the string contains a mix of both.")
# Out:
#   File <string>:4
#     elif text.isletters():
#                           ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# # QUESTION 13

# %% [markdown]
# ## Create a program that determines if a string is a single word (no spaces) or multiple words.

# %%
str=input("Enter a string")
if " " in str:
    print("the string contains multiple words.")
else:
    print("the string is a single word.")
# Out:
# Enter a string hello
# the string is a single word.

# %% [markdown]
# # QUESTION 14

# %% [markdown]
# # Write a program that checks if a name starts with a vowel or consonant.

# %%
name=input("Enter your name")
first_letter=name[0].lower()
if first_letter in "aeious":
    print("the name starts with a vowel.")
else:
    print("the name starts with a consonant.")
# Out:
# Enter your name Best
# the name starts with a consonant.

# %% [markdown]
# # QUESTION 15

# %% [markdown]
# ## Write a program that checks if a sentence starts with a capital letter and ends with proper punctuation (.,!,or ?).

# %%
sentence=input("Enter sentence")
if sentence[0].isupper() and sentence[-1] in ".!?":
    print(f"{sentence} is properly formatted")
else:
    print(f"{sentence} is not prp

# %% [markdown]
# ## QUESTION 16

# %% [markdown]
# ## Create a program that determines if a word is a palindrome (reads the same forwords and backwards).

# %%
word=input("Enter a word:")
if word==word[::-1]:
   print("the word is palindrome.")
else:
    print("the word is not palindrome.")
# Out:
# Enter a word: best
# the word is not palindrome.

# %% [markdown]
# ## QUESTION 17

# %% [markdown]
# # Write a program that checks if a phone number is in the format "XXX-XXX-XXXX" where X is a digit.
